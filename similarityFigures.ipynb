# %% [markdown]
# # Setup
# User must insert their own token for the neuprint client.

# %%
import connection_utils
import neuron_criteria
import visualization_utils

# %%
clock_df = neuron_criteria.getClock()
ids_by_type = neuron_criteria.bodyIds_by_type()
sLNv_IDs = ids_by_type['s-LNv']
LNd_IDs = ids_by_type['LNd']

# %%
from neuprint import Client
c = Client('neuprint.janelia.org', dataset='hemibrain:v1.2.1', token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImRiaW5na29AZ21haWwuY29tIiwibGV2ZWwiOiJub2F1dGgiLCJpbWFnZS11cmwiOiJodHRwczovL2xoMy5nb29nbGV1c2VyY29udGVudC5jb20vYS0vQU9oMTRHajF0YVhzbmtrdG5MZXNscWZfRE5nWGRENGhNdURIRHdqcEFpS09jNW89czk2LWM_c3o9NTA_c3o9NTAiLCJleHAiOjE4MjMyNTkxMzB9.RK54d39xkn27FTmo19vj_P-rLVlfGQVKN33r6G3wuPU')

# %% [markdown]
# # Supervenns

# %%
conn_df_out = connection_utils.clock_neuron_connections(clock_df, "out", min_weight = 1)

# %%
visualization_utils.supervenn_comps(conn_df_out, clock_df, "LNd", "out", bodyIds = LNd_IDs, weighted = False)

# %%
# bodyIds overrides whatever group name is provided in case the group name is for other identifying purposes
evening_IDs = ids_by_type['LNd'] + [ids_by_type['5th s-LNv']]
visualization_utils.supervenn_comps(conn_df_out, clock_df, "evening cells", "out", bodyIds = evening_IDs, weighted = False)

# %% [markdown]
# # Jaccards

# %%
labels = clock_df.loc[clock_df['bodyId'].isin(LNd_IDs), 'seqInstance'].reset_index()['seqInstance']
labels
# Out:
# 0    LNd_R_4
# 1    LNd_R_5
# 2    LNd_R_6
# 3    LNd_R_1
# 4    LNd_R_2
# 5    LNd_R_3
# Name: seqInstance, dtype: object

# %%
evening_IDs
# Out:
# [296544364,
#  448260940,
#  5813021192,
#  5813056917,
#  5813064789,
#  5813069648,
#  511051477]
